# %% [markdown]
# ### Example showcasing how to access the generated and downloaded xarrays

# %%
import xarray as xr

# Open NetCDF4 file
ds = xr.open_dataset('Sample_xarrays_generated/India_Goa_RCP4.5_2011-2040_marginal_land_final_energy_potential_data.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                 (x: 9, y: 12)
# Coordinates:
#     latitude                (x, y) float64 ...
#     longitude               (x, y) float64 ...
# Dimensions without coordinates: x, y
# Data variables:
#     total_energy_potential  (y, x) float64 ...

# %%
latitude_values = ds.coords['latitude'].values
latitude_values
# Out:
# array([[15.83333333, 15.75      , 15.66666667, 15.58333333, 15.5       ,
#         15.41666667, 15.33333333, 15.25      , 15.16666667, 15.08333333,
#         15.        , 14.91666667],
#        [15.83333333, 15.75      , 15.66666667, 15.58333333, 15.5       ,
#         15.41666667, 15.33333333, 15.25      , 15.16666667, 15.08333333,
#         15.        , 14.91666667],
#        [15.83333333, 15.75      , 15.66666667, 15.58333333, 15.5       ,
#         15.41666667, 15.33333333, 15.25      , 15.16666667, 15.08333333,
#         15.        , 14.91666667],
#        [15.83333333, 15.75      , 15.66666667, 15.58333333, 15.5       ,
#         15.41666667, 15.33333333, 15.25      , 15.16666667, 15.08333333,
#         15.        , 14.91666667],
#        [15.83333333, 15.75      , 15.66666667, 15.58333333, 15.5       ,
#         15.41666667, 15.33333333, 15.25      , 15.16666667, 15.08333333,
#         15.        , 14.91666667],
# ...

# %%
# Accessing variables
data_variable_values = ds.variables['total_energy_potential'].values
data_variable_values
# Out:
# array([[    0.        ,     0.        , 25282.68052443,     0.        ,
#             0.        ,     0.        ,     0.        ,     0.        ,
#             0.        ],
#        [34436.41700417, 24866.04411149, 24696.92615387,     0.        ,
#             0.        ,     0.        ,     0.        ,     0.        ,
#             0.        ],
#        [    0.        , 33613.83707642, 26604.84550224, 26582.65296831,
#             0.        , 48733.65760828, 50318.96701131,     0.        ,
#             0.        ],
#        [    0.        , 39521.23199083, 33861.26132396, 29062.0913747 ,
#         22349.1264945 , 47461.90509486, 50307.14756751,     0.        ,
#             0.        ],
#        [    0.        ,     0.        , 38398.9201819 , 29166.23091569,
#         30075.50853457, 46853.66878491, 49852.3972923 ,     0.        ,
#             0.        ],
#        [    0.        ,     0.        , 37986.30725681, 27228.23038384,
# ...
