# %%
import netCDF4 as nc

# Specify the path to your NetCDF file
file_path = 'output_data.nc'

# Open the NetCDF file
with nc.Dataset(file_path, 'r') as ds:
    # Access variables and attributes
    variable_data = ds.variables['2010'][:]
    # ... perform other operations with the data

# Note: 'variable_name' and 'attribute_name' should be replaced with the actual variable and attribute names in your NetCDF file.

# %%
variable_data
# Out:
# masked_array(
#   data=[[[0.0000000e+00, 0.0000000e+00, 4.9229969e+01, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [3.3129105e+01, 6.6277130e+01, 6.6535713e+01, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [0.0000000e+00, 3.4465954e+01, 5.0560207e+01, ...,
#           2.8837566e+00, 0.0000000e+00, 0.0000000e+00],
#          ...,
#          [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ...,
#           5.2256870e+00, 4.7225844e-02, 0.0000000e+00],
#          [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ...,
#           3.6255460e+00, 0.0000000e+00, 0.0000000e+00],
#          [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#
#         [[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
# ...
